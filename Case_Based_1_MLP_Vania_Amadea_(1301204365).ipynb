# %% [markdown]
# ##CASE BASED 1 MLP

# %% [markdown]
# *   Vania Amadea
# *   1301204365
# *   IF4408

# %% [markdown]
# #IMPORT LIBRARY

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# #DATASET

# %% [markdown]
# *Import dataset dari google drive*

# %%
# !gdown --id 19666Rz7qb_27CqXahW6ZUJU1qpFYFYjf
# !gdown --id 1oOOrx9LN0BriIw4oymWKUsfrkfiQhg3E
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=19666Rz7qb_27CqXahW6ZUJU1qpFYFYjf
# To: /content/audit_risk.csv
# 100% 81.2k/81.2k [00:00<00:00, 67.8MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1oOOrx9LN0BriIw4oymWKUsfrkfiQhg3E
# To: /content/trial.csv
# 100% 40.0k/40.0k [00:00<00:00, 42.9MB/s]

# %% [markdown]
# *Read dan menampilkan data csv*

# %%
df_train = pd.read_csv('audit_risk.csv', index_col = None)
df_train
# Out:
#      Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  \
# 0            3.89          23    4.18      0.6   2.508    2.50      0.2
# 1            3.89           6    0.00      0.2   0.000    4.83      0.2
# 2            3.89           6    0.51      0.2   0.102    0.23      0.2
# 3            3.89           6    0.00      0.2   0.000   10.80      0.6
# 4            3.89           6    0.00      0.2   0.000    0.08      0.2
# ..            ...         ...     ...      ...     ...     ...      ...
# 771         55.57           9    0.49      0.2   0.098    0.40      0.2
# 772         55.57          16    0.47      0.2   0.094    0.37      0.2
# 773         55.57          14    0.24      0.2   0.048    0.04      0.2
# 774         55.57          18    0.20      0.2   0.040    0.00      0.2
# 775         55.57          15    0.00      0.2   0.000    0.00      0.2
#
#      Risk_B  TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  \
# ...

# %% [markdown]
# #DATA PREPROCESSING

# %% [markdown]
# *Ringkasan lengkap dari dataframe*

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sector_score    776 non-null    float64
#  1   LOCATION_ID     776 non-null    object
#  2   PARA_A          776 non-null    float64
#  3   Score_A         776 non-null    float64
#  4   Risk_A          776 non-null    float64
#  5   PARA_B          776 non-null    float64
#  6   Score_B         776 non-null    float64
#  7   Risk_B          776 non-null    float64
#  8   TOTAL           776 non-null    float64
#  9   numbers         776 non-null    float64
#  10  Score_B.1       776 non-null    float64
#  11  Risk_C          776 non-null    float64
#  12  Money_Value     775 non-null    float64
#  13  Score_MV        776 non-null    float64
#  14  Risk_D          776 non-null    float64
#  15  District_Loss   776 non-null    int64
#  16  PROB            776 non-null    float64
# ...

# %% [markdown]
# *Memeriksa adanya missing value pada dataframe*

# %%
df_train.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# dtype: int64

# %% [markdown]
# *Isi null dengan nilai mean*

# %%
df_train['Money_Value'].fillna((df_train['Money_Value'].mean()), inplace = True)

# %% [markdown]
# *Drop kolom LOCATION_ID dan TOTAL*

# %%
df_train.drop(['LOCATION_ID', 'TOTAL'], axis = 1, inplace = True)

# %% [markdown]
# *Memeriksa dataset dengan menampilkan 5 teratas*

# %%
df_train.head()
# Out:
#    Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  numbers  \
# 0          3.89    4.18      0.6   2.508    2.50      0.2   0.500      5.0
# 1          3.89    0.00      0.2   0.000    4.83      0.2   0.966      5.0
# 2          3.89    0.51      0.2   0.102    0.23      0.2   0.046      5.0
# 3          3.89    0.00      0.2   0.000   10.80      0.6   6.480      6.0
# 4          3.89    0.00      0.2   0.000    0.08      0.2   0.016      5.0
#
#    Score_B.1  Risk_C  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        0.2     1.0  ...     0.4        0   0.2     0.0    2.4
# 1        0.2     1.0  ...     0.4        0   0.2     0.0    2.0
# 2        0.2     1.0  ...     0.4        0   0.2     0.0    2.0
# 3        0.6     3.6  ...     0.4        0   0.2     0.0    4.4
# 4        0.2     1.0  ...     0.4        0   0.2     0.0    2.0
#
#    Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# ...

# %% [markdown]
# #VISUALISASI DATA

# %% [markdown]
# *Melihat banyaknya data 0 dan 1 pada kolom Risk (Target)*

# %%
sns.countplot(df_train['Risk'], label='Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# *x berisi nilai kecuali Risk, y berisi nilai Risk saja*

# %%
x = df_train.drop('Risk', axis = 'columns')
y = df_train['Risk']
x.head()
# Out:
#    Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  numbers  \
# 0          3.89    4.18      0.6   2.508    2.50      0.2   0.500      5.0
# 1          3.89    0.00      0.2   0.000    4.83      0.2   0.966      5.0
# 2          3.89    0.51      0.2   0.102    0.23      0.2   0.046      5.0
# 3          3.89    0.00      0.2   0.000   10.80      0.6   6.480      6.0
# 4          3.89    0.00      0.2   0.000    0.08      0.2   0.016      5.0
#
#    Score_B.1  Risk_C  ...  PROB  RiSk_E  History  Prob  Risk_F  Score  \
# 0        0.2     1.0  ...   0.2     0.4        0   0.2     0.0    2.4
# 1        0.2     1.0  ...   0.2     0.4        0   0.2     0.0    2.0
# 2        0.2     1.0  ...   0.2     0.4        0   0.2     0.0    2.0
# 3        0.6     3.6  ...   0.2     0.4        0   0.2     0.0    4.4
# 4        0.2     1.0  ...   0.2     0.4        0   0.2     0.0    2.0
#
#    Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Risk, dtype: int64

# %% [markdown]
# *Cek korelasi*

# %%
top_corr_features = df_train.corr().index
plt.figure(figsize=(20,20))
g=sns.heatmap(df_train[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# *Drop kolom Detection_Risk*

# %%
x = x.drop('Detection_Risk', axis = 1)
x.columns
# Out:
# Index(['Sector_score', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B', 'Score_B',
#        'Risk_B', 'numbers', 'Score_B.1', 'Risk_C', 'Money_Value', 'Score_MV',
#        'Risk_D', 'District_Loss', 'PROB', 'RiSk_E', 'History', 'Prob',
#        'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK', 'Audit_Risk'],
#       dtype='object')

# %% [markdown]
# #FEATURE SCALING

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y , test_size=0.2, stratify=y,random_state=2)

# %%
sc_x = StandardScaler()
x_train_scaled = pd.DataFrame(sc_x.fit_transform(x_train))
x_test_scaled = pd.DataFrame(sc_x.transform(x_test))

# %% [markdown]
# #MODEL MLP

# %%
mlp = MLPClassifier()
mlp.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPClassifier()

# %% [markdown]
# #EVALUASI HASIL

# %%
mlp.score(x_test, y_test)
# Out:
# 1.0
